# %%
import sqlite3

conn = sqlite3.connect('data/crime_data.db')
cursor = conn.cursor()

cursor.execute("SELECT `LSOA code`, `Crime type` FROM street WHERE `Crime type` = 'Burglary'")
results = cursor.fetchall()

conn.close()

# %%
import geopandas as gpd

wards_shapefile = gpd.read_file('WD_DEC_2022_UK_BSC.shp')

wards_shapefile = wards_shapefile[['WD22NM', 'geometry']]

# %%
import pandas as pd

lsoa_to_ward = pd.read_csv('lsoa_to_ward.csv')

lsoa_to_ward = lsoa_to_ward[['LSOA21CD', 'WD22NM']]

lsoa_to_ward
# Out:
#         LSOA21CD         WD22NM
# 0      E01004766  Astley Bridge
# 1      E01004770  Astley Bridge
# 2      E01004772  Astley Bridge
# 3      E01004771  Astley Bridge
# 4      E01004768  Astley Bridge
# ...          ...            ...
# 35667  W01001583      St Arvans
# 35668  W01001585   St Kingsmark
# 35669  W01001554           Town
# 35670  W01001598       West End
# 35671  W01001599        Wyesham
#
# [35672 rows x 2 columns]

# %%
crime_data = pd.DataFrame(results, columns=['LSOA code', 'Crime type'])

crime_data
# Out:
#          LSOA code Crime type
# 0        E01000249   Burglary
# 1        E01000292   Burglary
# 2        E01000292   Burglary
# 3        E01000292   Burglary
# 4        E01000292   Burglary
# ...            ...        ...
# 1532254  E01000137   Burglary
# 1532255  E01000139   Burglary
# 1532256  E01000139   Burglary
# 1532257  E01000140   Burglary
# 1532258  E01000143   Burglary
#
# [1532259 rows x 2 columns]

# %%
code_counts = crime_data['LSOA code'].value_counts()

code_counts
# Out:
# E01000146    17793
# E01000211    13153
# E01000316    12583
# E01000194    12349
# E01000251    12085
#              ...
# E01000127     3015
# E01000294     2915
# E01000169     2906
# E01000133     2680
# E01000185     2395
# Name: LSOA code, Length: 211, dtype: int64

# %%
code_counts = code_counts.reset_index()
code_counts.columns = ['LSOA code', 'Burglary Count']

ward_counts = code_counts.merge(lsoa_to_ward, how='inner', left_on='LSOA code', right_on='LSOA21CD')
ward_counts = ward_counts.groupby('WD22NM')['Burglary Count'].sum().reset_index()

ward_counts
# Out:
#                    WD22NM  Burglary Count
# 0             Barnet Vale           68826
# 1          Brunswick Park           63530
# 2               Burnt Oak           72215
# 3             Childs Hill          107627
# 4         Colindale North           26550
# 5         Colindale South            5512
# 6             Cricklewood           53375
# 7             East Barnet           64617
# 8           East Finchley           55454
# 9                 Edgware           63553
# 10            Edgwarebury           41274
# 11    Finchley Church End           80664
# 12          Friern Barnet           78003
# 13          Garden Suburb           54869
# 14          Golders Green           72363
# 15                 Hendon           96618
# 16            High Barnet           52523
# 17              Mill Hill           68104
# 18  Totteridge & Woodside           47378
# 19              Underhill           44303
# 20          West Finchley           84046
# 21            West Hendon           78689
# 22              Whetstone           51417
# 23              Woodhouse           54669

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

ward_shapefile = gpd.read_file("WD_DEC_2022_UK_BSC.shp")

ward_shapefile
# Out:
#          WD22CD         WD22NM       WD22NMW    LAD22CD        LAD22NM  \
# 0     E05000650  Astley Bridge           NaN  E08000001         Bolton
# 1     E05000651       Bradshaw           NaN  E08000001         Bolton
# 2     E05000652     Breightmet           NaN  E08000001         Bolton
# 3     E05000653  Bromley Cross           NaN  E08000001         Bolton
# 4     E05000654       Crompton           NaN  E08000001         Bolton
# ...         ...            ...           ...        ...            ...
# 8478  W05001796      St Arvans     Llanarfan  W06000021  Monmouthshire
# 8479  W05001797   St Kingsmark  Llangynfarch  W06000021  Monmouthshire
# 8480  W05001798           Town        Y Dref  W06000021  Monmouthshire
# 8481  W05001799       West End      West End  W06000021  Monmouthshire
# 8482  W05001800        Wyesham       Wyesham  W06000021  Monmouthshire
#
#        BNG_E   BNG_N     LONG      LAT                              GlobalID  \
# 0     370670  412906 -2.44479  53.6119  0bd74ced-7727-4bc0-b107-8a420d42529c
# 1     374590  413058 -2.38555  53.6135  be678b65-9e25-4433-b811-d4da36361375
# 2     374437  409641 -2.38758  53.5827  981a520e-e851-4e52-ad14-539950902469
# 3     372113  414150 -2.42309  53.6231  6a0d2fd3-f4c0-49da-8d88-d2c85b6991e2
# 4     371741  410493 -2.42838  53.5903  7c6cf1d4-ca89-40e1-9fcb-7f66bcac94f6
# ...      ...     ...      ...      ...                                   ...
# 8478  352206  199469 -2.69284  51.6919  a979aa87-7849-4c6e-8b5e-c3124dbdcf23
# 8479  352792  194843 -2.68374  51.6504  aaeff8bb-6f43-42fc-b905-17d65d2952bf
# 8480  350812  212580 -2.71486  51.8097  0bdcd579-a8e3-4722-ac47-cbaa6ba72ad1
# 8481  347579  187362 -2.75795  51.5827  36c97a00-b1fe-4b8f-be35-792c25e2ad43
# 8482  353175  213098 -2.68066  51.8145  4f465521-f94f-4668-b32d-4fc8d99a2140
#
#                                                geometry
# 0     POLYGON ((372403.302 411764.003, 372018.802 41...
# 1     POLYGON ((375025.397 414992.099, 375013.679 41...
# 2     POLYGON ((375150.804 410809.796, 375331.198 40...
# 3     POLYGON ((373286.299 414364.499, 373564.100 41...
# 4     POLYGON ((373168.601 411597.801, 373367.397 41...
# ...                                                 ...
# 8478  POLYGON ((353870.761 205106.999, 353651.700 20...
# 8479  POLYGON ((352716.397 196049.301, 353192.500 19...
# 8480  POLYGON ((351948.073 213452.162, 351110.300 21...
# 8481  POLYGON ((347034.530 188530.878, 347599.829 18...
# 8482  POLYGON ((355272.704 214366.797, 355287.001 21...
#
# [8483 rows x 11 columns]

# %%
merged_data = ward_shapefile.merge(ward_counts, how='inner', left_on='WD22NM', right_on='WD22NM')
merged_data = merged_data[merged_data['LAD22NM'] == 'Barnet']

fig, ax = plt.subplots(figsize=(12, 10))
merged_data.plot(column='Burglary Count', cmap='cool', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)
merged_data.apply(lambda x: ax.annotate(text=x['WD22NM'], xy=x.geometry.centroid.coords[0], ha='center', fontsize=8), axis=1)
ax.set_title('Burglary Count Heatmap 2011 - 2023')
ax.set_axis_off()
plt.savefig('burglary_heatmap_total.png', dpi=300)
plt.show()
